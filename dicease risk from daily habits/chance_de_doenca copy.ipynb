# %% [markdown]
# # Introdução
#
# O trabalho realizado será para o tratamento e a pesquisa com dados voltados à saúde dos indivíduos submetidos aos testes, de modo a identificar alguma relação entre as informações obtidas e a classificação de saudável ou não saudável

# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/health_lifestyle_classification.csv", keep_default_na=False)
df.head(10)
# Out:
#    survey_code  age  gender      height     weight        bmi  bmi_estimated  \
# 0            1   56    Male  173.416872  56.886640  18.915925      18.915925
# 1            2   69  Female  163.207380  97.799859  36.716278      36.716278
# 2            3   46    Male  177.281966  80.687562  25.673050      25.673050
# 3            4   32  Female  172.101255  63.142868  21.318480      21.318480
# 4            5   60  Female  163.608816  40.000000  14.943302      14.943302
# 5            6   25    Male  186.788025  55.276111  15.843073      15.843073
# 6            7   78  Female  166.164733  65.035212  23.554335      23.554335
# 7            8   38  Female  163.783995  47.756125  17.802712      17.802712
# 8            9   56  Female  165.716460  47.257109  17.208216      17.208216
# 9           10   75    Male  151.310888  65.966591  28.812682      28.812682
#
#    bmi_scaled  bmi_corrected  waist_size  ... sunlight_exposure meals_per_day  \
# 0   56.747776      18.989117   72.165130  ...              High             5
# 1  110.148833      36.511417   85.598889  ...              High             5
# 2   77.019151      25.587429   90.295030  ...              High             4
# 3   63.955440      21.177109  100.504211  ...              High             1
# 4   44.829907      14.844299   69.021150  ...              High             1
# 5   47.529218      16.087835   86.591923  ...              High             4
# 6   70.663006      23.452755   67.838374  ...              High             2
# 7   53.408136      17.654781   73.071574  ...               Low             3
# 8   51.624648      17.199712   46.675208  ...              High             2
# 9   86.438045      29.088049   94.294368  ...              High             1
#
#    caffeine_intake  family_history pet_owner  electrolyte_level  \
# 0         Moderate              No       Yes                  0
# 1             High             Yes        No                  0
# 2         Moderate              No        No                  0
# 3             None              No       Yes                  0
# 4             High             Yes       Yes                  0
# 5             None             Yes       Yes                  0
# 6             None              No        No                  0
# 7         Moderate              No       Yes                  0
# 8         Moderate              No        No                  0
# 9             High             Yes        No                  0
#
#   gene_marker_flag  environmental_risk_score  daily_supplement_dosage   target
# 0              1.0                       5.5                -2.275502  healthy
# 1              1.0                       5.5                 6.239340  healthy
# 2              1.0                       5.5                 5.423737  healthy
# 3              1.0                       5.5                 8.388611  healthy
# 4              1.0                       5.5                 0.332622  healthy
# 5              1.0                       5.5                -8.985465  healthy
# 6                                        5.5                -6.296536  healthy
# 7              1.0                       5.5                 7.875266  healthy
# 8                                        5.5                -8.055654  healthy
# 9              1.0                       5.5                -3.035162  healthy
#
# [10 rows x 48 columns]

# %% [markdown]
# Nas primeiras linhas, já podemos ver dados ausentes nas colunas `caffeine_intake` e `gene_marker_flag`

# %%
print(df.columns)
# Out:
# Index(['survey_code', 'age', 'gender', 'height', 'weight', 'bmi',
#        'bmi_estimated', 'bmi_scaled', 'bmi_corrected', 'waist_size',
#        'blood_pressure', 'heart_rate', 'cholesterol', 'glucose', 'insulin',
#        'sleep_hours', 'sleep_quality', 'work_hours', 'physical_activity',
#        'daily_steps', 'calorie_intake', 'sugar_intake', 'alcohol_consumption',
#        'smoking_level', 'water_intake', 'screen_time', 'stress_level',
#        'mental_health_score', 'mental_health_support', 'education_level',
#        'job_type', 'occupation', 'income', 'diet_type', 'exercise_type',
#        'device_usage', 'healthcare_access', 'insurance', 'sunlight_exposure',
#        'meals_per_day', 'caffeine_intake', 'family_history', 'pet_owner',
#        'electrolyte_level', 'gene_marker_flag', 'environmental_risk_score',
#        'daily_supplement_dosage', 'target'],
#       dtype='object')

# %% [markdown]
# colunas da tabela:
# - `'survey_code'` - identificação do usuário *
# - `'age'` - idade
# - `'gender'` - gênero *
# - `'height'` - altura *
# - `'weight'` - peso *
# - `'bmi'` - Índice de Massa Corpórea (IMC)
#     - `'bmi_estimated'` - IMC estimado *
#     - `'bmi_scaled'` - IMC escalonado (normalizado) *
#     - `'bmi_corrected'` - IMC corrigido *
# - `'waist_size'` - tamanho de cintura *
# - `'blood_pressure'` - pressão sanguínea sistólica (mm Hg)
# - `'heart_rate'` - nível de batimento cardíaco
# - `'cholesterol'` - colesterol (mg/dL)
# - `'glucose'` - glicose
# - `'insulin'` - insulina
# - `'sleep_hours'` - horas de sono *
# - `'sleep_quality'` - qualidade do sono
# - `'work_hours'` - horas de trabalho *
# - `'physical_activity'` - nível de atividade física *
# - `'daily_steps'` - passos diários *
# - `'calorie_intake'` - ingestão calórica *
# - `'sugar_intake'` - ingestão de açúcar *
# - `'alcohol_consumption'` - consumo de álcool *
# - `'smoking_level'` - nível de tabagismo *
# - `'water_intake'` - ingestão de água *
# - `'screen_time'` - tempo de tela
# - `'stress_level'` - nível de estresse
# - `'mental_health_score'` - pontuação de saúde mental
# - `'mental_health_support'` - recebimento de apoio para saúde mental *
# - `'education_level'` - nível de escolaridade *
# - `'job_type'` - tipo de emprego (por exemplo, tempo integral, parcial) *
# - `'occupation'` - ocupação ou profissão
# - `'income'` - renda (pessoal ou familiar) *
# - `'diet_type'` - tipo de dieta (por exemplo, vegetariana, mediterrânea, etc.)
# - `'exercise_type'` - tipo de exercício (por exemplo, cardio, musculação)
# - `'device_usage'` - uso de dispositivos (por exemplo, rastreadores fitness)
# - `'healthcare_access'` - acesso a cuidados de saúde
# - `'insurance'` - posse de seguro de saúde
# - `'sunlight_exposure'` - exposição à luz solar
# - `'meals_per_day'` - refeições por dia
# - `'caffeine_intake'` - ingestão de cafeína
# - `'family_history'` - histórico familiar de doenças
# - `'pet_owner'` - posse de animal de estimação
# - `'electrolyte_level'` - nível de eletrólitos (como sódio, potássio) *
# - `'gene_marker_flag'` - sinalizador de marcador genético (indicador de risco) *
# - `'environmental_risk_score'` - pontuação de risco ambiental (poluição, etc.) *
# - `'daily_supplement_dosage'` - dosagem diária de suplementos *
# - `'target'` - Variável Alvo (o resultado ou desfecho que o modelo tentará prever) *

# %%
print(df.columns[df.isna().any()])
# Out:
# Index([], dtype='object')
